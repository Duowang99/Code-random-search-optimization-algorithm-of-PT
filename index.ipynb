       0.00917482, 0.00996652, 0.00903295, 0.00900037, 0.00962556,
       0.00941612, 0.0102525 , 0.00805574, 0.00940844, 0.00928874,
       0.00894403, 0.00878789, 0.00931938, 0.00902006, 0.00942571,
       0.00903563, 0.00959038, 0.00849265, 0.0088245 , 0.01000642,
       0.00878803, 0.00906996, 0.0085101 , 0.00852553, 0.0088038 ,
       0.00830932, 0.00973595, 0.00800338, 0.00772854, 0.00896509])

# %% [markdown]
# # top5

# %%
Akinson_diff_top5 = np.array([0.01990345, 0.02037855, 0.0203716 , 0.02064472, 0.02033554,
       0.02175156, 0.01646027, 0.01710632, 0.01502871, 0.01989219,
       0.01614299, 0.02021812, 0.01837998, 0.01778787, 0.01941777,
       0.02119928, 0.01828158, 0.01874258, 0.01931408, 0.01792248,
       0.01799318, 0.0177568 , 0.01823908, 0.01862729, 0.01751319,
       0.01916808, 0.02190321, 0.01500417, 0.01802484, 0.01787226,
       0.01639672, 0.01625353, 0.01931316, 0.01804703, 0.01792928,
       0.02034697, 0.01882717, 0.02096695, 0.01858693, 0.01985657,
       0.01646651, 0.01805502, 0.01753913, 0.01779155, 0.01697424,
       0.01651157, 0.02006451, 0.01622974, 0.01679039, 0.01731939])

# %%
Pietra_diff_top5 = np.array([0.0594973 , 0.0592166 , 0.05931357, 0.05977956, 0.05998529,
       0.06121493, 0.05232379, 0.05426539, 0.05098919, 0.05835601,
       0.05176064, 0.05922646, 0.05560603, 0.05639785, 0.0583311 ,
       0.0598126 , 0.05578127, 0.05700536, 0.05805224, 0.05526871,
       0.05557966, 0.05525369, 0.05584044, 0.05630124, 0.05451836,
       0.05784288, 0.0618429 , 0.05196687, 0.05571188, 0.05553483,
       0.05325693, 0.05505881, 0.05690875, 0.05613935, 0.05577311,
       0.05915116, 0.05713871, 0.060615  , 0.05806639, 0.05739016,
       0.05337847, 0.05498894, 0.05559157, 0.05497162, 0.05489802,
       0.05302074, 0.05842757, 0.05473944, 0.05434773, 0.05343493])

# %%
Theil_diff_top5 = np.array([0.00982289, 0.00970652, 0.00978415, 0.0099306 , 0.00978246,
       0.01049436, 0.00788103, 0.00821887, 0.00720702, 0.00955312,
       0.00768098, 0.00982712, 0.00896082, 0.0086996 , 0.00938633,
       0.01013268, 0.00878485, 0.00913613, 0.00937679, 0.00860694,
       0.00866147, 0.00872687, 0.00892281, 0.00896285, 0.00847368,
       0.00928145, 0.01053026, 0.00734567, 0.00858876, 0.00871271,
       0.00797171, 0.00801383, 0.00929494, 0.00866968, 0.0087432 ,
       0.00984745, 0.00915141, 0.0104466 , 0.00911452, 0.00949576,
       0.00794492, 0.0087372 , 0.00853467, 0.00858517, 0.00830895,
       0.00807016, 0.00961113, 0.00796015, 0.00809485, 0.00816666])

# %% [markdown]
# # top3

# %%
Akinson_diff_top3 = np.array([0.01852229, 0.01996108, 0.02089231, 0.01904403, 0.02189724,
       0.02057325, 0.01830779, 0.01788627, 0.01403243, 0.01989219,
       0.01655768, 0.01902105, 0.01997396, 0.01778787, 0.02058243,
       0.02197891, 0.01823254, 0.01848353, 0.01812001, 0.01837167,
       0.0182618 , 0.01830835, 0.01823173, 0.02008959, 0.01910014,
       0.01785449, 0.02140815, 0.01490445, 0.01963448, 0.01827919,
       0.01599536, 0.01633976, 0.02120579, 0.01838595, 0.01806865,
       0.01914741, 0.01874028, 0.01885152, 0.01885192, 0.0201897 ,
       0.01862183, 0.01872765, 0.01949724, 0.01900608, 0.01740966,
       0.015625  , 0.0200917 , 0.01688355, 0.01707388, 0.01956319])

# %%
Pietra_diff_top3 = np.array([0.05671444, 0.05831608, 0.06064206, 0.05657737, 0.06180217,
       0.05926214, 0.05582537, 0.05570603, 0.04962349, 0.05835601,
       0.05235936, 0.05722762, 0.05818892, 0.05639785, 0.06084849,
       0.06126796, 0.05584507, 0.05710975, 0.05643883, 0.05579917,
       0.05649362, 0.05607447, 0.05585619, 0.05856017, 0.0569921 ,
       0.05506962, 0.06092284, 0.05196058, 0.05843058, 0.05641718,
       0.05332357, 0.05501572, 0.06083696, 0.05666818, 0.05613632,
       0.05688583, 0.05659404, 0.05608733, 0.05772901, 0.05876423,
       0.0570778 , 0.05668361, 0.05844067, 0.0576497 , 0.05531335,
       0.05097365, 0.05913125, 0.05573175, 0.0545267 , 0.05846082])

# %%
Theil_diff_top3 = np.array([0.00907355, 0.00952881, 0.01003232, 0.00913255, 0.01052308,
       0.00989294, 0.00875596, 0.00864784, 0.00671686, 0.00955312,
       0.00796753, 0.00924672, 0.00973889, 0.0086996 , 0.01002615,
       0.01052098, 0.008751  , 0.00902562, 0.00883286, 0.00884201,
       0.00881711, 0.00896414, 0.00895823, 0.00978315, 0.00933463,
       0.00858971, 0.01032814, 0.00728377, 0.00938056, 0.00887739,
       0.00777901, 0.00805567, 0.01030985, 0.00882824, 0.00875704,
       0.00920718, 0.00912744, 0.00928841, 0.00914473, 0.00962138,
       0.00907774, 0.0091169 , 0.00957975, 0.00920027, 0.00850074,
       0.00755572, 0.00961963, 0.00830718, 0.0082499 , 0.00941373])

# %%
initial_Akinson = np.array([0.01859879, 0.01947665, 0.02043045, 0.01959584, 0.02005543,
       0.02024651, 0.01762005, 0.01782875, 0.01524035, 0.01925689,
       0.01629813, 0.019106  , 0.01883279, 0.01776775, 0.01917697,
       0.02112189, 0.01899034, 0.0187322 , 0.01856639, 0.01812706,
       0.01883218, 0.01848077, 0.01890749, 0.01854682, 0.0181554 ,
       0.01791871, 0.02102019, 0.01562427, 0.01896025, 0.01852985,
       0.01698814, 0.01650017, 0.01968833, 0.01823547, 0.01808292,
       0.01925445, 0.01911721, 0.01816152, 0.01810899, 0.01930074,
       0.01787195, 0.0181959 , 0.01765707, 0.01821293, 0.01652834,
       0.01747018, 0.01984259, 0.01612561, 0.01695841, 0.01828573])

# %%
kwargs = {'cumulative': True}

sns.distplot(  initial_Akinson, hist_kws=kwargs, kde_kws=kwargs,color = 'black')
sns.distplot(  Akinson_diff_average, hist_kws=kwargs, kde_kws=kwargs,color = 'red')
#sns.distplot(  Akinson_diff_top10, hist_kws=kwargs, kde_kws=kwargs,color = 'yellow')
#sns.distplot(  Akinson_diff_top50, hist_kws=kwargs, kde_kws=kwargs,color = 'blue')
#sns.distplot(  Akinson_diff_top75, hist_kws=kwargs, kde_kws=kwargs,color = 'green')
sns.distplot(  Akinson_diff_top5, hist_kws=kwargs, kde_kws=kwargs,color = 'yellow')
sns.distplot(  Akinson_diff_top3, hist_kws=kwargs, kde_kws=kwargs,color = 'orange')
# Out:
# /home/dwang/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/dwang/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
ax_1 = sns.kdeplot(initial_Akinson,cumulative=True, color = 'black', label='Initial')
ax_2 = sns.kdeplot(Akinson_diff_average,cumulative=True, color = 'red',label='m=100')
ax_3 = sns.kdeplot(Akinson_diff_top5,cumulative=True, color = 'blue',label='m=5')
ax_4 = sns.kdeplot(Akinson_diff_top75,cumulative=True, color = 'green',label='m=75')
plt.legend()

# %%
#ax_1 = sns.kdeplot(initial_Akinson,cumulative=True, color = 'black', label='Initial')
ax_2 = sns.kdeplot(Pietra_diff_average,cumulative=True, color = 'red',label='m=100')
ax_3 = sns.kdeplot(Pietra_diff_top5,cumulative=True, color = 'orange',label='m=5')
ax_4 = sns.kdeplot(Pietra_diff_top10, cumulative=True,color = 'yellow',label='m=10')
ax_5 = sns.kdeplot(Pietra_diff_top50, cumulative=True,color = 'green',label='m=50')
ax_6 = sns.kdeplot(Pietra_diff_top75,cumulative=True, color = 'blue',label='m=75')
plt.legend()

# %%
plt.figure(figsize=(8,6))
ax_1 = sns.kdeplot(initial_Akinson,cumulative=True, color = 'black', label='Initial graphs')
ax_2 = sns.kdeplot(Akinson_diff_average,cumulative=True, color = 'black',label='Efficiency-based algorithm',linestyle = ':')
ax_3 = sns.kdeplot(Akinson_diff_top5,cumulative=True, color = 'black',label='Equality-based algorithm',linestyle = 'dashdot')
# ax_4 = sns.kdeplot(Akinson_diff_top10, cumulative=True,color = 'yellow',label='m=10')
# ax_5 = sns.kdeplot(Akinson_diff_top50, cumulative=True,color = 'green',label='m=50')
# ax_6 = sns.kdeplot(Akinson_diff_top75,cumulative=True, color = 'blue',label='m=75')
plt.legend()
plt.show()

# %%
#ax_1 = sns.kdeplot(initial_Akinson,cumulative=True, color = 'black', label='Initial')
ax_2 = sns.kdeplot(Theil_diff_average,cumulative=True, color = 'red',label='m=100')
ax_3 = sns.kdeplot(Theil_diff_top5,cumulative=True, color = 'orange',label='m=5')
ax_4 = sns.kdeplot(Theil_diff_top10, cumulative=True,color = 'yellow',label='m=10')
ax_5 = sns.kdeplot(Theil_diff_top50, cumulative=True,color = 'green',label='m=50')
ax_6 = sns.kdeplot(Theil_diff_top75,cumulative=True, color = 'blue',label='m=75')
plt.legend()
