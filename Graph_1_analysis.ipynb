#        29725.20707278, 30318.67752093, 29123.06550636, 27425.04881575,
#        25202.58254126, 22270.14063466, 22868.62940985, 26491.80166533,
# ...

# %%
y_1
# Out:
# array([  679.35330089,   906.49606697,  1162.04760984,  1261.44797235,
#          311.14757916, -1010.3427697 ,    88.53378454,   499.80567328,
#          228.54391466,  -370.6648451 ,   761.18006982,  1022.68127868,
#         1532.06881662,  2030.54064772,   325.4726977 ,   108.29727312,
#          689.90912021,   786.94282723,    72.38223889,  -823.25829265,
#          670.24894977,  1019.96861349,  1546.27149469,  2131.91943207,
#          455.38988131,   368.59840954,   862.28960685,   703.84764381,
#          911.21644858,   112.42651989,   401.2370856 ,   692.82731522,
#         1103.97531705,  1619.90265825,  1096.09254054,  -286.35443332,
#         -528.78095302,  -351.45719731,   604.5898051 ,   600.25389193,
#          257.5020115 ,   483.66108497,   416.71114234,   847.61588479,
#         1167.7061634 ,   939.93420652,  -325.58376847,    84.72049496,
#          792.32485248,   754.6608013 ,   155.52479734,   282.34847014,
# ...

# %%
l2=plt.scatter(x,y_1,label='ef-G_1')
l3=plt.scatter(x,y_2,label='eq-G_1')
#plt.plot(x,y_1,'ro-',x,y_2,'g+-',x,y_3,'b^-')
#plt.title('The Lasers in Three Conditions')
plt.xlabel('acc_before')
plt.ylabel('acc_after')
plt.legend(loc='upper left')
plt.show()

# %%
import seaborn as sns

#create scatterplot with regression line and confidence interval lines
#sns.regplot(x, y_1,label='ef-G_1',order=3)
sns.regplot(x, (y_2-y_1)*60,label='eq-G_1',order=2)
plt.legend(loc='upper left')
plt.ylim((-50000, 50000))
# Out:
# /home/dwang/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (-50000.0, 50000.0)

# %%
sns.regplot(x, y_1,label='ef-G_1',order=3)
sns.regplot(x, y_2,label='eq-G_1',order=3)
plt.legend(loc='upper left')
#plt.ylim((-3000, 3000))

# %%
#create scatterplot with regression line and confidence interval lines
sns.regplot(x, y_1*60,label='ef-G_1',order=2, marker="+" , scatter_kws={"s": 20},line_kws={"lw":2, 'linestyle':'--','label': 'ef-G_1 line'})
sns.regplot(x, y_2*60,label='eq-G_1',order=2, marker='o' , scatter_kws={"s": 20},line_kws={"lw":2, 'linestyle':'-','label': 'eq-G_1 line'})
plt.legend(loc='best')
plt.ylim((-5000, 55000))
plt.xlabel('persons / hour before optimization')
plt.ylabel('persons / hour after optimization')
plt.show()

# %%
#

# %%
d= b-a

# %%
e= c-a

# %%
d_1 = d.copy()

# %%
e_1 = e.copy()

# %%
d_1.sort()

# %%
e_1.sort()

# %%
index = np.array( [i for i in range(100)] )

# %%
plt.plot(index,d_1,'r',label='G_1')
plt.plot(index,e_1,'g',label='G_2')

# %%
import seaborn as sns

# %%
kwargs = {'cumulative': True}
sns.distplot( d_1 , hist_kws=kwargs, kde_kws=kwargs,color = 'black')
sns.distplot( e_1 , hist_kws=kwargs, kde_kws=kwargs,color = 'red')
# Out:
# /home/dwang/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/dwang/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
np.mean(d_1)
# Out:
# 602.6838715311997

# %%
np.mean(e_1)
# Out:
# 627.3001583704
